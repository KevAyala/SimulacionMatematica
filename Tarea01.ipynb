# %% [markdown]
# # Sobre mí
#
# ¡Hola!, soy *Kevin Emiliano Ayala Montoya* tengo 19 años y soy estudiante de segundo semestre de Ingenería en Sistemas Computacionales.
#
# Soy una persona que le gusta analizar lo que pasa a su alrededor y hablando de gustos tambien me gusta mucho la música, el cine y la programación
#
# ## Mis gustos...
#
# Como ya dije me encanta la música y de hecho tengo mis favoritas, aquí un top 5 de mis canciones favoritas:
#
# 1. __m.A.A.d city__ - Kendrick Lamar
# 2. __Power Freaks__ - Jean Dawson
# 3. __Time for Us__ - Nicolas Jaar
# 4. __I Know__ - Big Sean, Jhené Aiko
# 5. __fue mejor__ - Kali Uchis, SZA
#
# Y así como tengo canciones favoritas también tengo un albúm favorito:
# ![][cover]
#
# [cover]: https://images.genius.com/c73c9700388a7942fd8b986062854155.1000x1000x1.png "FAMOUZ"
#
# ## Sobre mi carrera
#
# ### Topología de Redes de Computadoras
#
# La topología de red no es otra cosa que la forma en que se conectan las computadoras para intercambiar datos entre sí. Es como una famila de comunicación, que define cómo se va a diseñar la red tanto de manera física, como de manera lógica.
#
# Existen varios tipos de Topologías de Red:
#
# * Bus
# * Anillo
# * Estrella
# * Estrella Extendida
# * De Árbol
# * Malla
#
# ![image.png](attachment:image.png)
#
# Fuente: https://conocesobreinformatica.com/topologias-de-red/
#
#
# ### Ecuación de una recta
#
# Es importante conocer la ecuación de una recta dada por $y = mx+b$
